# %% [markdown]
# ### 모델 학습
#
# - DecisionTreeRegressor
# - KNeighborsRegressor
# - LinearRegression
# - RandomForestRegressor
# - kFold
#
# #### 모델 평가
# - Mean Absolute Error

# %%
import pandas as pd

train = pd.read_csv('C:/Users/user/LikeLion_AI/DACON/Parking_demand/parking_data_preprocessing_train.csv')
test = pd.read_csv('C:/Users/user/LikeLion_AI/DACON/Parking_demand/parking_data_preprocessing_test.csv')
sub = pd.read_csv('C:/Users/user/LikeLion_AI/data/CSV/DACON_Parking_Demand/sample_submission.csv')
age = pd.read_csv('C:/Users/user/LikeLion_AI/data/CSV/DACON_Parking_Demand/age_gender_info.csv')

train.shape, test.shape, sub.shape, age.shape
# Out:
# ((2869, 16), (1007, 16), (150, 2), (16, 23))

# %%
train.columns
# Out:
# Index(['index', '단지코드', '총세대수', '임대건물구분', '지역', '공급유형', '전용면적', '전용면적별세대수',
#        '공가수', '자격유형', '임대보증금', '임대료', '도보 10분거리 내 지하철역 수(환승노선 수 반영)',
#        '도보 10분거리 내 버스정류장 수', '단지내주차면수', '등록차량수'],
#       dtype='object')

# %%
test.drop('level_0', axis=1, inplace=True)
test
# Out:
#       index   단지코드      총세대수  임대건물구분  지역  공급유형      전용면적  전용면적별세대수        공가수  \
# 0         0  C1072  5.727773     1.0   1     5  0.952031  1.233906   5.090909
# 1         1  C1072  5.727773     1.0   1     5  1.198010  0.311159   5.090909
# 2         2  C1072  5.727773     1.0   1     5  1.201163  1.190987   5.090909
# 3         3  C1072  5.727773     1.0   1     5  1.201163  1.276824   5.090909
# 4         4  C1072  5.727773     1.0   1     5  1.360945  0.633047   5.090909
# ...     ...    ...       ...     ...  ..   ...       ...       ...        ...
# 1002   1017  C1267  5.106216     1.0   2     9  0.846210  1.341202  13.818182
# 1003   1018  C2189  2.800944     1.0  12     5  0.580609  1.019313  16.363636
# 1004   1019  C2189  2.800944     1.0  12     5  0.580609  0.203863  16.363636
# 1005   1020  C2189  2.800944     1.0  12     5  0.940117  2.156652  16.363636
# 1006   1021  C2189  2.800944     1.0  12     5  1.177687  0.633047  16.363636
#
#       자격유형     임대보증금       임대료  도보 10분거리 내 지하철역 수(환승노선 수 반영)  \
# 0        7  0.449034  0.195940                           0.0
# 1        0  0.731320  0.263924                           0.0
# 2        7  0.731320  0.263924                           0.0
# 3        7  0.731320  0.263924                           0.0
# 4        7  0.890402  0.316928                           0.0
# ...    ...       ...       ...                           ...
# 1002    11  0.335075  0.143542                           0.0
# 1003     7  0.108232  0.101540                           0.0
# 1004     7  0.108232  0.101540                           0.0
# 1005     7  0.247859  0.144758                           0.0
# 1006     7  0.360598  0.169534                           0.0
#
#       도보 10분거리 내 버스정류장 수   단지내주차면수
# 0                    2.0  7.507003
# 1                    2.0  7.507003
# 2                    2.0  7.507003
# 3                    2.0  7.507003
# 4                    2.0  7.507003
# ...                  ...       ...
# 1002                 1.0  5.086835
# 1003                 2.0  3.215686
# 1004                 2.0  3.215686
# 1005                 2.0  3.215686
# 1006                 2.0  3.215686
#
# [1007 rows x 15 columns]

# %% [markdown]
# ### DecisionTreeRegressor

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.tree import DecisionTreeRegressor

sel = ['총세대수', '임대건물구분', '지역', '전용면적', '전용면적별세대수', 
       '자격유형', '임대보증금', '임대료', '도보 10분거리 내 지하철역 수(환승노선 수 반영)', '단지내주차면수']

X = train[sel]
y = train['등록차량수']

for size in range(10, 51):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=size/100, random_state=10)

    dtree = DecisionTreeRegressor()
    dtree.fit(X_train, y_train)
    pred = dtree.predict(X_test)

    score = round(mean_absolute_error(y_test, pred), 3)
    print(f'size : {size/100} 일 때 = score : {score}')
# Out:
# size : 0.1 일 때 = score : 12.836
# size : 0.11 일 때 = score : 14.829
# size : 0.12 일 때 = score : 21.142
# size : 0.13 일 때 = score : 22.265
# size : 0.14 일 때 = score : 18.162
# size : 0.15 일 때 = score : 18.216
# size : 0.16 일 때 = score : 15.487
# size : 0.17 일 때 = score : 16.586
# size : 0.18 일 때 = score : 18.957
# size : 0.19 일 때 = score : 16.941
# size : 0.2 일 때 = score : 16.456
# size : 0.21 일 때 = score : 13.894
# size : 0.22 일 때 = score : 14.625
# size : 0.23 일 때 = score : 16.962
# size : 0.24 일 때 = score : 18.695
# size : 0.25 일 때 = score : 15.149
# size : 0.26 일 때 = score : 21.796
# size : 0.27 일 때 = score : 23.316
# size : 0.28 일 때 = score : 22.521
# size : 0.29 일 때 = score : 20.086
# size : 0.3 일 때 = score : 18.798
# size : 0.31 일 때 = score : 20.41
# size : 0.32 일 때 = score : 19.869
# size : 0.33 일 때 = score : 18.291
# size : 0.34 일 때 = score : 24.51
# size : 0.35 일 때 = score : 21.314
# size : 0.36 일 때 = score : 24.133
# size : 0.37 일 때 = score : 25.225
# size : 0.38 일 때 = score : 30.02
# size : 0.39 일 때 = score : 25.706
# size : 0.4 일 때 = score : 29.385
# size : 0.41 일 때 = score : 28.705
# size : 0.42 일 때 = score : 30.202
# size : 0.43 일 때 = score : 33.969
# size : 0.44 일 때 = score : 31.741
# size : 0.45 일 때 = score : 29.887
# size : 0.46 일 때 = score : 31.84
# size : 0.47 일 때 = score : 33.196
# size : 0.48 일 때 = score : 33.802
# size : 0.49 일 때 = score : 35.541
# size : 0.5 일 때 = score : 35.308

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
sel = ['총세대수', '임대건물구분', '지역', '전용면적', '전용면적별세대수', 
       '자격유형', '임대보증금', '임대료', '도보 10분거리 내 지하철역 수(환승노선 수 반영)', '단지내주차면수']

X_train = train[sel]
X_test = test[sel]
y_train = train['등록차량수']

L_Regression = LinearRegression()
L_Regression.fit(X_train, y_train)
pred = L_Regression.predict(X_test)
pred
# Out:
# array([631.3851507 , 698.91172155, 642.79725137, ..., 239.15468107,
#        252.10323505, 266.96519675])

# %%
test['등록차량수'] = pred

test['코드별차량수평균'] = test.groupby('단지코드')['등록차량수'].transform(np.mean)

test.head(20)
# Out:
#     index   단지코드       총세대수  임대건물구분  지역  공급유형      전용면적  전용면적별세대수       공가수  \
# 0       0  C1072   5.727773     1.0   1     5  0.952031  1.233906  5.090909
# 1       1  C1072   5.727773     1.0   1     5  1.198010  0.311159  5.090909
# 2       2  C1072   5.727773     1.0   1     5  1.201163  1.190987  5.090909
# 3       3  C1072   5.727773     1.0   1     5  1.201163  1.276824  5.090909
# 4       4  C1072   5.727773     1.0   1     5  1.360945  0.633047  5.090909
# 5       5  C1072   5.727773     1.0   1     5  1.369705  0.536481  5.090909
# 6       6  C1072   5.727773     1.0   1     5  1.378465  2.113734  5.090909
# 7       7  C1072   5.727773     1.0   1     5  1.378465  0.708155  5.090909
# 8       8  C1128  10.448466     1.0   1     5  0.952031  3.937768  3.272727
# 9       9  C1128  10.448466     1.0   1     5  0.952031  0.311159  3.272727
# 10     10  C1128  10.448466     1.0   1     5  0.952031  0.225322  3.272727
# 11     11  C1128  10.448466     1.0   1     5  1.198010  0.633047  3.272727
# 12     12  C1128  10.448466     1.0   1     5  1.201163  1.233906  3.272727
# 13     13  C1128  10.448466     1.0   1     5  1.201163  1.920601  3.272727
# 14     14  C1128  10.448466     1.0   1     5  1.369705  0.246781  3.272727
# 15     15  C1128  10.448466     1.0   1     5  1.378465  4.452790  3.272727
# 16     16  C1128  10.448466     1.0   1     5  1.378465  1.469957  3.272727
# 17     17  C1456   4.665618     1.0   7     5  0.728126  0.869099  6.545455
# 18     18  C1456   4.665618     1.0   7     5  0.944322  1.223176  6.545455
# 19     19  C1456   4.665618     1.0   7     5  0.944322  0.364807  6.545455
#
#     자격유형     임대보증금       임대료  도보 10분거리 내 지하철역 수(환승노선 수 반영)  \
# 0      7  0.449034  0.195940                           0.0
# 1      0  0.731320  0.263924                           0.0
# 2      7  0.731320  0.263924                           0.0
# 3      7  0.731320  0.263924                           0.0
# 4      7  0.890402  0.316928                           0.0
# 5      7  0.890402  0.316928                           0.0
# 6      7  0.890402  0.316928                           0.0
# 7      7  0.890402  0.316928                           0.0
# 8      7  0.449034  0.195940                           0.0
# 9      7  0.449034  0.195940                           0.0
# 10     0  0.449034  0.195940                           0.0
# 11     0  0.731320  0.263924                           0.0
# 12     0  0.731320  0.263924                           0.0
# 13     7  0.731320  0.263924                           0.0
# 14     0  0.890402  0.316928                           0.0
# 15     7  0.890402  0.316928                           0.0
# 16     7  0.890402  0.316928                           0.0
# 17     0  0.382317  0.157881                           0.0
# 18     0  0.526023  0.198667                           0.0
# 19     0  0.526023  0.198667                           0.0
#
#     도보 10분거리 내 버스정류장 수    단지내주차면수        등록차량수     코드별차량수평균
# 0                  2.0   7.507003   661.136300   672.543629
# 1                  2.0   7.507003   671.515329   672.543629
# 2                  2.0   7.507003   670.842623   672.543629
# 3                  2.0   7.507003   670.776993   672.543629
# 4                  2.0   7.507003   676.798374   672.543629
# 5                  2.0   7.507003   676.872207   672.543629
# 6                  2.0   7.507003   675.666260   672.543629
# 7                  2.0   7.507003   676.740948   672.543629
# 8                  3.0  13.478992  1123.085235  1133.162059
# 9                  3.0  13.478992  1125.858095  1133.162059
# 10                 3.0  13.478992  1125.923725  1133.162059
# 11                 3.0  13.478992  1135.285491  1133.162059
# 12                 3.0  13.478992  1134.826083  1133.162059
# 13                 3.0  13.478992  1134.301044  1133.162059
# 14                 3.0  13.478992  1141.109983  1133.162059
# 15                 3.0  13.478992  1137.894122  1133.162059
# 16                 3.0  13.478992  1140.174758  1133.162059
# 17                16.0   5.983193   538.476537   549.036082
# 18                16.0   5.983193   543.163036   549.036082
# 19                16.0   5.983193   543.819334   549.036082

# %%
test_new = test.drop_duplicates(['단지코드'], keep='first').reset_index()

sub_df = test_new[['단지코드', '코드별차량수평균']]
sub_df.columns = ['code', 'num']

sub_df
# Out:
#       code          num
# 0    C1072   672.543629
# 1    C1128  1133.162059
# 2    C1456   549.036082
# 3    C1840   536.242163
# 4    C1332  1040.792218
# ..     ...          ...
# 142  C2456   287.073784
# 143  C1266   583.552313
# 144  C2152    77.639466
# 145  C1267   447.404915
# 146  C2189   312.531165
#
# [147 rows x 2 columns]

# %%
sub_df.loc[147] = {'code':'C2675', 'num':0}
sub_df.loc[148] = {'code':'C2335', 'num':0}
sub_df.loc[149] = {'code':'C1327', 'num':0}
sub_df
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#       code          num
# 0    C1072   672.543629
# 1    C1128  1133.162059
# 2    C1456   549.036082
# 3    C1840   536.242163
# 4    C1332  1040.792218
# ..     ...          ...
# 145  C1267   447.404915
# 146  C2189   312.531165
# 147  C2675     0.000000
# 148  C2335     0.000000
# 149  C1327     0.000000
#
# [150 rows x 2 columns]

# %%
sub_df.to_csv('07_17_second_submit.csv', index=False)

# %% [markdown]
# ### 128.66393점 / (344위 / 425위)
#
# 1 % : 90.66564
#
# 4 % : 94.74703
#
# 10 % : 98.53061
#
# 100위 : 105.59628

# %% [markdown]
# ### 라쏘 회귀

# %%
from sklearn.linear_model import Ridge, Lasso, LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split

for i in range(1, 4):
    ex_X = PolynomialFeatures(degree=i, include_bias=False).fit_transform(X_train)
    X_train1, X_test1, y_train1, y_test1 = train_test_split(ex_X, y_train)
    print(f'< degree = {i} >')
    
    for j in range(1, 51):
        L1 = Lasso(alpha=j/10).fit(X_train1, y_train1)
        L2 = Ridge(alpha=j/10).fit(X_train1, y_train1)
        
        print(f'< alpha = {j/10} >')
        print('Lasso 훈련 세트 점수 : {:.3f}'.format(L1.score(X_train1, y_train1)))
        print('Lasso 훈련 세트 점수 : {:.3f}'.format(L1.score(X_test1, y_test1)))
        print()
        
        print('Ridge 훈련 세트 점수 : {:.3f}'.format(L2.score(X_train1, y_train1)))
        print('Ridge 훈련 세트 점수 : {:.3f}'.format(L2.score(X_test1, y_test1)))
        print()
    
    print('=====================================================')
# Out:
# < degree = 1 >
# < alpha = 0.1 >
# Lasso 훈련 세트 점수 : 0.759
# Lasso 훈련 세트 점수 : 0.778
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 0.2 >
# Lasso 훈련 세트 점수 : 0.759
# Lasso 훈련 세트 점수 : 0.778
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 0.3 >
# Lasso 훈련 세트 점수 : 0.759
# Lasso 훈련 세트 점수 : 0.778
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 0.4 >
# Lasso 훈련 세트 점수 : 0.759
# Lasso 훈련 세트 점수 : 0.778
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 0.5 >
# Lasso 훈련 세트 점수 : 0.759
# Lasso 훈련 세트 점수 : 0.778
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 0.6 >
# Lasso 훈련 세트 점수 : 0.759
# Lasso 훈련 세트 점수 : 0.778
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 0.7 >
# Lasso 훈련 세트 점수 : 0.759
# Lasso 훈련 세트 점수 : 0.778
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 0.8 >
# Lasso 훈련 세트 점수 : 0.759
# Lasso 훈련 세트 점수 : 0.778
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 0.9 >
# Lasso 훈련 세트 점수 : 0.759
# Lasso 훈련 세트 점수 : 0.778
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 1.0 >
# Lasso 훈련 세트 점수 : 0.759
# Lasso 훈련 세트 점수 : 0.778
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 1.1 >
# Lasso 훈련 세트 점수 : 0.759
# Lasso 훈련 세트 점수 : 0.778
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 1.2 >
# Lasso 훈련 세트 점수 : 0.759
# Lasso 훈련 세트 점수 : 0.778
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 1.3 >
# Lasso 훈련 세트 점수 : 0.759
# Lasso 훈련 세트 점수 : 0.778
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 1.4 >
# Lasso 훈련 세트 점수 : 0.759
# Lasso 훈련 세트 점수 : 0.778
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 1.5 >
# Lasso 훈련 세트 점수 : 0.759
# Lasso 훈련 세트 점수 : 0.778
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 1.6 >
# Lasso 훈련 세트 점수 : 0.759
# Lasso 훈련 세트 점수 : 0.778
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 1.7 >
# Lasso 훈련 세트 점수 : 0.759
# Lasso 훈련 세트 점수 : 0.778
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 1.8 >
# Lasso 훈련 세트 점수 : 0.759
# Lasso 훈련 세트 점수 : 0.778
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 1.9 >
# Lasso 훈련 세트 점수 : 0.759
# Lasso 훈련 세트 점수 : 0.778
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 2.0 >
# Lasso 훈련 세트 점수 : 0.759
# Lasso 훈련 세트 점수 : 0.778
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 2.1 >
# Lasso 훈련 세트 점수 : 0.759
# Lasso 훈련 세트 점수 : 0.778
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 2.2 >
# Lasso 훈련 세트 점수 : 0.759
# Lasso 훈련 세트 점수 : 0.778
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 2.3 >
# Lasso 훈련 세트 점수 : 0.759
# Lasso 훈련 세트 점수 : 0.777
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 2.4 >
# Lasso 훈련 세트 점수 : 0.758
# Lasso 훈련 세트 점수 : 0.777
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 2.5 >
# Lasso 훈련 세트 점수 : 0.758
# Lasso 훈련 세트 점수 : 0.777
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 2.6 >
# Lasso 훈련 세트 점수 : 0.758
# Lasso 훈련 세트 점수 : 0.777
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 2.7 >
# Lasso 훈련 세트 점수 : 0.758
# Lasso 훈련 세트 점수 : 0.777
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 2.8 >
# Lasso 훈련 세트 점수 : 0.758
# Lasso 훈련 세트 점수 : 0.777
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 2.9 >
# Lasso 훈련 세트 점수 : 0.758
# Lasso 훈련 세트 점수 : 0.777
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 3.0 >
# Lasso 훈련 세트 점수 : 0.758
# Lasso 훈련 세트 점수 : 0.777
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 3.1 >
# Lasso 훈련 세트 점수 : 0.758
# Lasso 훈련 세트 점수 : 0.777
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 3.2 >
# Lasso 훈련 세트 점수 : 0.758
# Lasso 훈련 세트 점수 : 0.777
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 3.3 >
# Lasso 훈련 세트 점수 : 0.758
# Lasso 훈련 세트 점수 : 0.777
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 3.4 >
# Lasso 훈련 세트 점수 : 0.758
# Lasso 훈련 세트 점수 : 0.777
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 3.5 >
# Lasso 훈련 세트 점수 : 0.758
# Lasso 훈련 세트 점수 : 0.777
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 3.6 >
# Lasso 훈련 세트 점수 : 0.758
# Lasso 훈련 세트 점수 : 0.777
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 3.7 >
# Lasso 훈련 세트 점수 : 0.758
# Lasso 훈련 세트 점수 : 0.777
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 3.8 >
# Lasso 훈련 세트 점수 : 0.758
# Lasso 훈련 세트 점수 : 0.777
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 3.9 >
# Lasso 훈련 세트 점수 : 0.758
# Lasso 훈련 세트 점수 : 0.777
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 4.0 >
# Lasso 훈련 세트 점수 : 0.758
# Lasso 훈련 세트 점수 : 0.776
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 4.1 >
# Lasso 훈련 세트 점수 : 0.758
# Lasso 훈련 세트 점수 : 0.776
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 4.2 >
# Lasso 훈련 세트 점수 : 0.757
# Lasso 훈련 세트 점수 : 0.776
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 4.3 >
# Lasso 훈련 세트 점수 : 0.757
# Lasso 훈련 세트 점수 : 0.776
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 4.4 >
# Lasso 훈련 세트 점수 : 0.757
# Lasso 훈련 세트 점수 : 0.776
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 4.5 >
# Lasso 훈련 세트 점수 : 0.757
# Lasso 훈련 세트 점수 : 0.776
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 4.6 >
# Lasso 훈련 세트 점수 : 0.757
# Lasso 훈련 세트 점수 : 0.776
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 4.7 >
# Lasso 훈련 세트 점수 : 0.757
# Lasso 훈련 세트 점수 : 0.776
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 4.8 >
# Lasso 훈련 세트 점수 : 0.757
# Lasso 훈련 세트 점수 : 0.776
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 4.9 >
# Lasso 훈련 세트 점수 : 0.757
# Lasso 훈련 세트 점수 : 0.776
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# < alpha = 5.0 >
# Lasso 훈련 세트 점수 : 0.757
# Lasso 훈련 세트 점수 : 0.776
#
# Ridge 훈련 세트 점수 : 0.759
# Ridge 훈련 세트 점수 : 0.778
#
# =====================================================
# < degree = 2 >
# < alpha = 0.1 >
# Lasso 훈련 세트 점수 : 0.840
# Lasso 훈련 세트 점수 : 0.820
#
# Ridge 훈련 세트 점수 : 0.842
# Ridge 훈련 세트 점수 : 0.822
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32159580.189016376, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32031468.48149057, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31476396.181822907, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 0.2 >
# Lasso 훈련 세트 점수 : 0.840
# Lasso 훈련 세트 점수 : 0.821
#
# Ridge 훈련 세트 점수 : 0.842
# Ridge 훈련 세트 점수 : 0.822
#
# < alpha = 0.3 >
# Lasso 훈련 세트 점수 : 0.840
# Lasso 훈련 세트 점수 : 0.821
#
# Ridge 훈련 세트 점수 : 0.842
# Ridge 훈련 세트 점수 : 0.822
#
# < alpha = 0.4 >
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30691383.671081997, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29675536.307507087, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# Lasso 훈련 세트 점수 : 0.839
# Lasso 훈련 세트 점수 : 0.821
#
# Ridge 훈련 세트 점수 : 0.842
# Ridge 훈련 세트 점수 : 0.822
#
# < alpha = 0.5 >
# Lasso 훈련 세트 점수 : 0.839
# Lasso 훈련 세트 점수 : 0.820
#
# Ridge 훈련 세트 점수 : 0.842
# Ridge 훈련 세트 점수 : 0.822
#
# < alpha = 0.6 >
# Lasso 훈련 세트 점수 : 0.838
# Lasso 훈련 세트 점수 : 0.820
#
# Ridge 훈련 세트 점수 : 0.842
# Ridge 훈련 세트 점수 : 0.822
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 28463335.38670126, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26977464.67348365, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25385804.151048686, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 0.7 >
# Lasso 훈련 세트 점수 : 0.838
# Lasso 훈련 세트 점수 : 0.820
#
# Ridge 훈련 세트 점수 : 0.842
# Ridge 훈련 세트 점수 : 0.822
#
# < alpha = 0.8 >
# Lasso 훈련 세트 점수 : 0.837
# Lasso 훈련 세트 점수 : 0.819
#
# Ridge 훈련 세트 점수 : 0.842
# Ridge 훈련 세트 점수 : 0.822
#
# < alpha = 0.9 >
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23486132.457220472, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19815132.90105049, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14450554.460154831, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# Lasso 훈련 세트 점수 : 0.837
# Lasso 훈련 세트 점수 : 0.818
#
# Ridge 훈련 세트 점수 : 0.842
# Ridge 훈련 세트 점수 : 0.822
#
# < alpha = 1.0 >
# Lasso 훈련 세트 점수 : 0.836
# Lasso 훈련 세트 점수 : 0.818
#
# Ridge 훈련 세트 점수 : 0.842
# Ridge 훈련 세트 점수 : 0.822
#
# < alpha = 1.1 >
# Lasso 훈련 세트 점수 : 0.836
# Lasso 훈련 세트 점수 : 0.817
#
# Ridge 훈련 세트 점수 : 0.842
# Ridge 훈련 세트 점수 : 0.822
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8648157.219684768, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7260628.901389241, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5978155.91879002, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 1.2 >
# Lasso 훈련 세트 점수 : 0.835
# Lasso 훈련 세트 점수 : 0.817
#
# Ridge 훈련 세트 점수 : 0.842
# Ridge 훈련 세트 점수 : 0.822
#
# < alpha = 1.3 >
# Lasso 훈련 세트 점수 : 0.835
# Lasso 훈련 세트 점수 : 0.817
#
# Ridge 훈련 세트 점수 : 0.842
# Ridge 훈련 세트 점수 : 0.822
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3204501.6864949614, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2143083.359163195, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 1.4 >
# Lasso 훈련 세트 점수 : 0.834
# Lasso 훈련 세트 점수 : 0.817
#
# Ridge 훈련 세트 점수 : 0.842
# Ridge 훈련 세트 점수 : 0.822
#
# < alpha = 1.5 >
# Lasso 훈련 세트 점수 : 0.834
# Lasso 훈련 세트 점수 : 0.816
#
# Ridge 훈련 세트 점수 : 0.842
# Ridge 훈련 세트 점수 : 0.822
#
# < alpha = 1.6 >
# Lasso 훈련 세트 점수 : 0.834
# Lasso 훈련 세트 점수 : 0.816
#
# Ridge 훈련 세트 점수 : 0.842
# Ridge 훈련 세트 점수 : 0.822
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1702160.4806998, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1278911.515935704, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1026455.719223395, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 1.7 >
# Lasso 훈련 세트 점수 : 0.833
# Lasso 훈련 세트 점수 : 0.816
#
# Ridge 훈련 세트 점수 : 0.842
# Ridge 훈련 세트 점수 : 0.822
#
# < alpha = 1.8 >
# Lasso 훈련 세트 점수 : 0.833
# Lasso 훈련 세트 점수 : 0.816
#
# Ridge 훈련 세트 점수 : 0.842
# Ridge 훈련 세트 점수 : 0.822
#
# < alpha = 1.9 >
# Lasso 훈련 세트 점수 : 0.833
# Lasso 훈련 세트 점수 : 0.816
#
# Ridge 훈련 세트 점수 : 0.842
# Ridge 훈련 세트 점수 : 0.821
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 524225.74337040633, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 321095.72667077184, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 330672.1239459142, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 2.0 >
# Lasso 훈련 세트 점수 : 0.832
# Lasso 훈련 세트 점수 : 0.815
#
# Ridge 훈련 세트 점수 : 0.842
# Ridge 훈련 세트 점수 : 0.821
#
# < alpha = 2.1 >
# Lasso 훈련 세트 점수 : 0.832
# Lasso 훈련 세트 점수 : 0.815
#
# Ridge 훈련 세트 점수 : 0.842
# Ridge 훈련 세트 점수 : 0.821
#
# < alpha = 2.2 >
# Lasso 훈련 세트 점수 : 0.832
# Lasso 훈련 세트 점수 : 0.815
#
# Ridge 훈련 세트 점수 : 0.842
# Ridge 훈련 세트 점수 : 0.821
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 414371.74893808365, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 348232.7241583094, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 256281.09985982627, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 2.3 >
# Lasso 훈련 세트 점수 : 0.832
# Lasso 훈련 세트 점수 : 0.815
#
# Ridge 훈련 세트 점수 : 0.842
# Ridge 훈련 세트 점수 : 0.821
#
# < alpha = 2.4 >
# Lasso 훈련 세트 점수 : 0.831
# Lasso 훈련 세트 점수 : 0.814
#
# Ridge 훈련 세트 점수 : 0.842
# Ridge 훈련 세트 점수 : 0.821
#
# < alpha = 2.5 >
# Lasso 훈련 세트 점수 : 0.831
# Lasso 훈련 세트 점수 : 0.814
#
# Ridge 훈련 세트 점수 : 0.841
# Ridge 훈련 세트 점수 : 0.821
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 100154.43464110792, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 114534.17121912539, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 221753.94400472194, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 2.6 >
# Lasso 훈련 세트 점수 : 0.831
# Lasso 훈련 세트 점수 : 0.814
#
# Ridge 훈련 세트 점수 : 0.841
# Ridge 훈련 세트 점수 : 0.821
#
# < alpha = 2.7 >
# Lasso 훈련 세트 점수 : 0.830
# Lasso 훈련 세트 점수 : 0.813
#
# Ridge 훈련 세트 점수 : 0.841
# Ridge 훈련 세트 점수 : 0.821
#
# < alpha = 2.8 >
# Lasso 훈련 세트 점수 : 0.830
# Lasso 훈련 세트 점수 : 0.813
#
# Ridge 훈련 세트 점수 : 0.841
# Ridge 훈련 세트 점수 : 0.821
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 167419.56554754823, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 137184.10589196533, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 89878.74642442912, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 2.9 >
# Lasso 훈련 세트 점수 : 0.830
# Lasso 훈련 세트 점수 : 0.813
#
# Ridge 훈련 세트 점수 : 0.841
# Ridge 훈련 세트 점수 : 0.821
#
# < alpha = 3.0 >
# Lasso 훈련 세트 점수 : 0.829
# Lasso 훈련 세트 점수 : 0.812
#
# Ridge 훈련 세트 점수 : 0.841
# Ridge 훈련 세트 점수 : 0.821
#
# < alpha = 3.1 >
# Lasso 훈련 세트 점수 : 0.829
# Lasso 훈련 세트 점수 : 0.812
#
# Ridge 훈련 세트 점수 : 0.841
# Ridge 훈련 세트 점수 : 0.821
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 151932.3257976994, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 146013.9569748342, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 137843.11954358965, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 3.2 >
# Lasso 훈련 세트 점수 : 0.829
# Lasso 훈련 세트 점수 : 0.812
#
# Ridge 훈련 세트 점수 : 0.841
# Ridge 훈련 세트 점수 : 0.821
#
# < alpha = 3.3 >
# Lasso 훈련 세트 점수 : 0.828
# Lasso 훈련 세트 점수 : 0.812
#
# Ridge 훈련 세트 점수 : 0.841
# Ridge 훈련 세트 점수 : 0.821
#
# < alpha = 3.4 >
# Lasso 훈련 세트 점수 : 0.828
# Lasso 훈련 세트 점수 : 0.811
#
# Ridge 훈련 세트 점수 : 0.841
# Ridge 훈련 세트 점수 : 0.821
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 135772.35196653008, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 130591.37246935815, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 126589.341773808, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 3.5 >
# Lasso 훈련 세트 점수 : 0.828
# Lasso 훈련 세트 점수 : 0.811
#
# Ridge 훈련 세트 점수 : 0.841
# Ridge 훈련 세트 점수 : 0.821
#
# < alpha = 3.6 >
# Lasso 훈련 세트 점수 : 0.827
# Lasso 훈련 세트 점수 : 0.811
#
# Ridge 훈련 세트 점수 : 0.841
# Ridge 훈련 세트 점수 : 0.821
#
# < alpha = 3.7 >
# Lasso 훈련 세트 점수 : 0.827
# Lasso 훈련 세트 점수 : 0.810
#
# Ridge 훈련 세트 점수 : 0.841
# Ridge 훈련 세트 점수 : 0.821
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 122736.41268344223, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 123489.80547171831, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 99674.24753433466, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 3.8 >
# Lasso 훈련 세트 점수 : 0.827
# Lasso 훈련 세트 점수 : 0.810
#
# Ridge 훈련 세트 점수 : 0.841
# Ridge 훈련 세트 점수 : 0.821
#
# < alpha = 3.9 >
# Lasso 훈련 세트 점수 : 0.827
# Lasso 훈련 세트 점수 : 0.810
#
# Ridge 훈련 세트 점수 : 0.841
# Ridge 훈련 세트 점수 : 0.821
#
# < alpha = 4.0 >
# Lasso 훈련 세트 점수 : 0.826
# Lasso 훈련 세트 점수 : 0.809
#
# Ridge 훈련 세트 점수 : 0.841
# Ridge 훈련 세트 점수 : 0.821
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 108805.39339412749, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 73104.29580661654, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 47786.097066670656, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 4.1 >
# Lasso 훈련 세트 점수 : 0.826
# Lasso 훈련 세트 점수 : 0.809
#
# Ridge 훈련 세트 점수 : 0.841
# Ridge 훈련 세트 점수 : 0.821
#
# < alpha = 4.2 >
# Lasso 훈련 세트 점수 : 0.826
# Lasso 훈련 세트 점수 : 0.809
#
# Ridge 훈련 세트 점수 : 0.841
# Ridge 훈련 세트 점수 : 0.821
#
# < alpha = 4.3 >
# Lasso 훈련 세트 점수 : 0.826
# Lasso 훈련 세트 점수 : 0.809
#
# Ridge 훈련 세트 점수 : 0.841
# Ridge 훈련 세트 점수 : 0.821
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51313.219797462225, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 52869.35649256408, tolerance: 40334.11415732217
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 4.4 >
# Lasso 훈련 세트 점수 : 0.825
# Lasso 훈련 세트 점수 : 0.808
#
# Ridge 훈련 세트 점수 : 0.841
# Ridge 훈련 세트 점수 : 0.821
#
# < alpha = 4.5 >
# Lasso 훈련 세트 점수 : 0.825
# Lasso 훈련 세트 점수 : 0.808
#
# Ridge 훈련 세트 점수 : 0.841
# Ridge 훈련 세트 점수 : 0.821
#
# < alpha = 4.6 >
# Lasso 훈련 세트 점수 : 0.825
# Lasso 훈련 세트 점수 : 0.808
#
# Ridge 훈련 세트 점수 : 0.841
# Ridge 훈련 세트 점수 : 0.821
#
# < alpha = 4.7 >
# Lasso 훈련 세트 점수 : 0.825
# Lasso 훈련 세트 점수 : 0.807
#
# Ridge 훈련 세트 점수 : 0.841
# Ridge 훈련 세트 점수 : 0.821
#
# < alpha = 4.8 >
# Lasso 훈련 세트 점수 : 0.825
# Lasso 훈련 세트 점수 : 0.807
#
# Ridge 훈련 세트 점수 : 0.841
# Ridge 훈련 세트 점수 : 0.821
#
# < alpha = 4.9 >
# Lasso 훈련 세트 점수 : 0.824
# Lasso 훈련 세트 점수 : 0.807
#
# Ridge 훈련 세트 점수 : 0.841
# Ridge 훈련 세트 점수 : 0.821
#
# < alpha = 5.0 >
# Lasso 훈련 세트 점수 : 0.824
# Lasso 훈련 세트 점수 : 0.806
#
# Ridge 훈련 세트 점수 : 0.841
# Ridge 훈련 세트 점수 : 0.821
#
# =====================================================
# < degree = 3 >
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22330799.46867265, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 0.1 >
# Lasso 훈련 세트 점수 : 0.894
# Lasso 훈련 세트 점수 : 0.859
#
# Ridge 훈련 세트 점수 : 0.915
# Ridge 훈련 세트 점수 : 0.715
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22897092.332402576, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 0.2 >
# Lasso 훈련 세트 점수 : 0.891
# Lasso 훈련 세트 점수 : 0.860
#
# Ridge 훈련 세트 점수 : 0.914
# Ridge 훈련 세트 점수 : 0.736
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23258854.484520495, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 0.3 >
# Lasso 훈련 세트 점수 : 0.890
# Lasso 훈련 세트 점수 : 0.861
#
# Ridge 훈련 세트 점수 : 0.914
# Ridge 훈련 세트 점수 : 0.745
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23523933.40382058, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 0.4 >
# Lasso 훈련 세트 점수 : 0.889
# Lasso 훈련 세트 점수 : 0.861
#
# Ridge 훈련 세트 점수 : 0.913
# Ridge 훈련 세트 점수 : 0.750
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23741938.308393486, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 0.5 >
# Lasso 훈련 세트 점수 : 0.888
# Lasso 훈련 세트 점수 : 0.862
#
# Ridge 훈련 세트 점수 : 0.913
# Ridge 훈련 세트 점수 : 0.753
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23895937.705514394, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 0.6 >
# Lasso 훈련 세트 점수 : 0.888
# Lasso 훈련 세트 점수 : 0.863
#
# Ridge 훈련 세트 점수 : 0.913
# Ridge 훈련 세트 점수 : 0.756
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24019083.367860187, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 0.7 >
# Lasso 훈련 세트 점수 : 0.887
# Lasso 훈련 세트 점수 : 0.863
#
# Ridge 훈련 세트 점수 : 0.912
# Ridge 훈련 세트 점수 : 0.758
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24112191.264769275, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 0.8 >
# Lasso 훈련 세트 점수 : 0.887
# Lasso 훈련 세트 점수 : 0.863
#
# Ridge 훈련 세트 점수 : 0.912
# Ridge 훈련 세트 점수 : 0.760
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24259436.365244035, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 0.9 >
# Lasso 훈련 세트 점수 : 0.886
# Lasso 훈련 세트 점수 : 0.863
#
# Ridge 훈련 세트 점수 : 0.912
# Ridge 훈련 세트 점수 : 0.762
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24398572.92135986, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 1.0 >
# Lasso 훈련 세트 점수 : 0.886
# Lasso 훈련 세트 점수 : 0.863
#
# Ridge 훈련 세트 점수 : 0.912
# Ridge 훈련 세트 점수 : 0.763
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24523795.15409282, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 1.1 >
# Lasso 훈련 세트 점수 : 0.885
# Lasso 훈련 세트 점수 : 0.863
#
# Ridge 훈련 세트 점수 : 0.911
# Ridge 훈련 세트 점수 : 0.764
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24629092.4922641, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 1.2 >
# Lasso 훈련 세트 점수 : 0.885
# Lasso 훈련 세트 점수 : 0.863
#
# Ridge 훈련 세트 점수 : 0.911
# Ridge 훈련 세트 점수 : 0.765
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24687292.810933094, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 1.3 >
# Lasso 훈련 세트 점수 : 0.884
# Lasso 훈련 세트 점수 : 0.862
#
# Ridge 훈련 세트 점수 : 0.911
# Ridge 훈련 세트 점수 : 0.766
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24803720.16684456, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 1.4 >
# Lasso 훈련 세트 점수 : 0.884
# Lasso 훈련 세트 점수 : 0.862
#
# Ridge 훈련 세트 점수 : 0.911
# Ridge 훈련 세트 점수 : 0.767
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24864241.868669946, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 1.5 >
# Lasso 훈련 세트 점수 : 0.883
# Lasso 훈련 세트 점수 : 0.862
#
# Ridge 훈련 세트 점수 : 0.911
# Ridge 훈련 세트 점수 : 0.768
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24934804.076632444, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 1.6 >
# Lasso 훈련 세트 점수 : 0.883
# Lasso 훈련 세트 점수 : 0.862
#
# Ridge 훈련 세트 점수 : 0.911
# Ridge 훈련 세트 점수 : 0.769
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24961891.348914117, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 1.7 >
# Lasso 훈련 세트 점수 : 0.883
# Lasso 훈련 세트 점수 : 0.862
#
# Ridge 훈련 세트 점수 : 0.911
# Ridge 훈련 세트 점수 : 0.770
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25046279.23542307, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 1.8 >
# Lasso 훈련 세트 점수 : 0.882
# Lasso 훈련 세트 점수 : 0.862
#
# Ridge 훈련 세트 점수 : 0.910
# Ridge 훈련 세트 점수 : 0.771
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25145645.939266536, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 1.9 >
# Lasso 훈련 세트 점수 : 0.882
# Lasso 훈련 세트 점수 : 0.861
#
# Ridge 훈련 세트 점수 : 0.910
# Ridge 훈련 세트 점수 : 0.772
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25185243.995708693, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 2.0 >
# Lasso 훈련 세트 점수 : 0.882
# Lasso 훈련 세트 점수 : 0.861
#
# Ridge 훈련 세트 점수 : 0.910
# Ridge 훈련 세트 점수 : 0.772
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25212648.233065803, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 2.1 >
# Lasso 훈련 세트 점수 : 0.881
# Lasso 훈련 세트 점수 : 0.861
#
# Ridge 훈련 세트 점수 : 0.910
# Ridge 훈련 세트 점수 : 0.773
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25252158.98447662, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 2.2 >
# Lasso 훈련 세트 점수 : 0.881
# Lasso 훈련 세트 점수 : 0.861
#
# Ridge 훈련 세트 점수 : 0.910
# Ridge 훈련 세트 점수 : 0.774
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25289488.24400004, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 2.3 >
# Lasso 훈련 세트 점수 : 0.880
# Lasso 훈련 세트 점수 : 0.860
#
# Ridge 훈련 세트 점수 : 0.910
# Ridge 훈련 세트 점수 : 0.775
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25325447.42803314, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 2.4 >
# Lasso 훈련 세트 점수 : 0.880
# Lasso 훈련 세트 점수 : 0.860
#
# Ridge 훈련 세트 점수 : 0.910
# Ridge 훈련 세트 점수 : 0.775
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25375346.82128435, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 2.5 >
# Lasso 훈련 세트 점수 : 0.879
# Lasso 훈련 세트 점수 : 0.860
#
# Ridge 훈련 세트 점수 : 0.910
# Ridge 훈련 세트 점수 : 0.776
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25415531.590196304, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 2.6 >
# Lasso 훈련 세트 점수 : 0.879
# Lasso 훈련 세트 점수 : 0.859
#
# Ridge 훈련 세트 점수 : 0.910
# Ridge 훈련 세트 점수 : 0.777
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25441743.077827685, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 2.7 >
# Lasso 훈련 세트 점수 : 0.879
# Lasso 훈련 세트 점수 : 0.859
#
# Ridge 훈련 세트 점수 : 0.910
# Ridge 훈련 세트 점수 : 0.777
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25471905.172949538, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 2.8 >
# Lasso 훈련 세트 점수 : 0.878
# Lasso 훈련 세트 점수 : 0.859
#
# Ridge 훈련 세트 점수 : 0.909
# Ridge 훈련 세트 점수 : 0.778
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25503276.240694396, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 2.9 >
# Lasso 훈련 세트 점수 : 0.878
# Lasso 훈련 세트 점수 : 0.858
#
# Ridge 훈련 세트 점수 : 0.909
# Ridge 훈련 세트 점수 : 0.779
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25525938.490702994, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 3.0 >
# Lasso 훈련 세트 점수 : 0.878
# Lasso 훈련 세트 점수 : 0.858
#
# Ridge 훈련 세트 점수 : 0.909
# Ridge 훈련 세트 점수 : 0.779
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25581751.297458306, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 3.1 >
# Lasso 훈련 세트 점수 : 0.877
# Lasso 훈련 세트 점수 : 0.857
#
# Ridge 훈련 세트 점수 : 0.909
# Ridge 훈련 세트 점수 : 0.780
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25588687.22905552, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 3.2 >
# Lasso 훈련 세트 점수 : 0.877
# Lasso 훈련 세트 점수 : 0.857
#
# Ridge 훈련 세트 점수 : 0.909
# Ridge 훈련 세트 점수 : 0.781
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25627148.096717242, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 3.3 >
# Lasso 훈련 세트 점수 : 0.877
# Lasso 훈련 세트 점수 : 0.857
#
# Ridge 훈련 세트 점수 : 0.909
# Ridge 훈련 세트 점수 : 0.781
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25641623.960403547, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 3.4 >
# Lasso 훈련 세트 점수 : 0.877
# Lasso 훈련 세트 점수 : 0.856
#
# Ridge 훈련 세트 점수 : 0.909
# Ridge 훈련 세트 점수 : 0.782
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25641875.408143345, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 3.5 >
# Lasso 훈련 세트 점수 : 0.877
# Lasso 훈련 세트 점수 : 0.856
#
# Ridge 훈련 세트 점수 : 0.909
# Ridge 훈련 세트 점수 : 0.783
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25641034.576813187, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 3.6 >
# Lasso 훈련 세트 점수 : 0.877
# Lasso 훈련 세트 점수 : 0.856
#
# Ridge 훈련 세트 점수 : 0.909
# Ridge 훈련 세트 점수 : 0.783
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25655748.065103054, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 3.7 >
# Lasso 훈련 세트 점수 : 0.876
# Lasso 훈련 세트 점수 : 0.856
#
# Ridge 훈련 세트 점수 : 0.909
# Ridge 훈련 세트 점수 : 0.784
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25659830.544890992, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 3.8 >
# Lasso 훈련 세트 점수 : 0.876
# Lasso 훈련 세트 점수 : 0.856
#
# Ridge 훈련 세트 점수 : 0.909
# Ridge 훈련 세트 점수 : 0.784
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25667001.002383493, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 3.9 >
# Lasso 훈련 세트 점수 : 0.876
# Lasso 훈련 세트 점수 : 0.856
#
# Ridge 훈련 세트 점수 : 0.909
# Ridge 훈련 세트 점수 : 0.785
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25671211.153907403, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 4.0 >
# Lasso 훈련 세트 점수 : 0.876
# Lasso 훈련 세트 점수 : 0.855
#
# Ridge 훈련 세트 점수 : 0.909
# Ridge 훈련 세트 점수 : 0.786
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25639624.430840116, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 4.1 >
# Lasso 훈련 세트 점수 : 0.876
# Lasso 훈련 세트 점수 : 0.855
#
# Ridge 훈련 세트 점수 : 0.909
# Ridge 훈련 세트 점수 : 0.786
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25627286.735846188, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 4.2 >
# Lasso 훈련 세트 점수 : 0.876
# Lasso 훈련 세트 점수 : 0.855
#
# Ridge 훈련 세트 점수 : 0.908
# Ridge 훈련 세트 점수 : 0.787
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25615536.282660246, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 4.3 >
# Lasso 훈련 세트 점수 : 0.875
# Lasso 훈련 세트 점수 : 0.855
#
# Ridge 훈련 세트 점수 : 0.908
# Ridge 훈련 세트 점수 : 0.787
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25620488.43547752, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 4.4 >
# Lasso 훈련 세트 점수 : 0.875
# Lasso 훈련 세트 점수 : 0.855
#
# Ridge 훈련 세트 점수 : 0.908
# Ridge 훈련 세트 점수 : 0.788
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25643211.23422637, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 4.5 >
# Lasso 훈련 세트 점수 : 0.875
# Lasso 훈련 세트 점수 : 0.855
#
# Ridge 훈련 세트 점수 : 0.908
# Ridge 훈련 세트 점수 : 0.789
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25650060.4874415, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 4.6 >
# Lasso 훈련 세트 점수 : 0.875
# Lasso 훈련 세트 점수 : 0.854
#
# Ridge 훈련 세트 점수 : 0.908
# Ridge 훈련 세트 점수 : 0.789
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25812336.713395007, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 4.7 >
# Lasso 훈련 세트 점수 : 0.875
# Lasso 훈련 세트 점수 : 0.854
#
# Ridge 훈련 세트 점수 : 0.908
# Ridge 훈련 세트 점수 : 0.790
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25881891.086067036, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 4.8 >
# Lasso 훈련 세트 점수 : 0.875
# Lasso 훈련 세트 점수 : 0.854
#
# Ridge 훈련 세트 점수 : 0.908
# Ridge 훈련 세트 점수 : 0.790
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26000458.078955926, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(
# < alpha = 4.9 >
# Lasso 훈련 세트 점수 : 0.875
# Lasso 훈련 세트 점수 : 0.854
#
# Ridge 훈련 세트 점수 : 0.908
# Ridge 훈련 세트 점수 : 0.791
#
# < alpha = 5.0 >
# Lasso 훈련 세트 점수 : 0.875
# Lasso 훈련 세트 점수 : 0.854
#
# Ridge 훈련 세트 점수 : 0.908
# Ridge 훈련 세트 점수 : 0.791
#
# =====================================================
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25986738.09248682, tolerance: 40281.70803217108
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# ```
# [ degree 3 ]
#
# < alpha = 1.2 >
# Lasso 훈련 세트 점수 : 0.885
# Lasso 훈련 세트 점수 : 0.863
#
# Ridge 훈련 세트 점수 : 0.911
# Ridge 훈련 세트 점수 : 0.765
# ```

# %%
sel = ['총세대수', '임대건물구분', '지역', '전용면적', '전용면적별세대수', 
       '자격유형', '임대보증금', '임대료', '도보 10분거리 내 지하철역 수(환승노선 수 반영)', '단지내주차면수']

X_train = train[sel]
X_test = test[sel]
y_train = train['등록차량수']

ex_X = PolynomialFeatures(degree=3, include_bias=False).fit_transform(X_train)
ex_test_X = PolynomialFeatures(degree=3, include_bias=False).fit_transform(X_test)

L1 = Lasso(alpha=1.2)
L1.fit(ex_X, y_train)

pred = L1.predict(ex_test_X)
pred
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33296164.09938202, tolerance: 53144.13773091669
#   model = cd_fast.enet_coordinate_descent(
# array([615.72560472, 657.63179471, 661.86467232, ..., 316.77540819,
#        324.22804926, 330.39480681])

# %% [markdown]
# ### 제출

# %%
test['등록차량수'] = pred

test['코드별차량수평균'] = test.groupby('단지코드')['등록차량수'].transform(np.mean)

test.head(20)
# Out:
#     index   단지코드       총세대수  임대건물구분  지역  공급유형      전용면적  전용면적별세대수       공가수  \
# 0       0  C1072   5.727773     1.0   1     5  0.952031  1.233906  5.090909
# 1       1  C1072   5.727773     1.0   1     5  1.198010  0.311159  5.090909
# 2       2  C1072   5.727773     1.0   1     5  1.201163  1.190987  5.090909
# 3       3  C1072   5.727773     1.0   1     5  1.201163  1.276824  5.090909
# 4       4  C1072   5.727773     1.0   1     5  1.360945  0.633047  5.090909
# 5       5  C1072   5.727773     1.0   1     5  1.369705  0.536481  5.090909
# 6       6  C1072   5.727773     1.0   1     5  1.378465  2.113734  5.090909
# 7       7  C1072   5.727773     1.0   1     5  1.378465  0.708155  5.090909
# 8       8  C1128  10.448466     1.0   1     5  0.952031  3.937768  3.272727
# 9       9  C1128  10.448466     1.0   1     5  0.952031  0.311159  3.272727
# 10     10  C1128  10.448466     1.0   1     5  0.952031  0.225322  3.272727
# 11     11  C1128  10.448466     1.0   1     5  1.198010  0.633047  3.272727
# 12     12  C1128  10.448466     1.0   1     5  1.201163  1.233906  3.272727
# 13     13  C1128  10.448466     1.0   1     5  1.201163  1.920601  3.272727
# 14     14  C1128  10.448466     1.0   1     5  1.369705  0.246781  3.272727
# 15     15  C1128  10.448466     1.0   1     5  1.378465  4.452790  3.272727
# 16     16  C1128  10.448466     1.0   1     5  1.378465  1.469957  3.272727
# 17     17  C1456   4.665618     1.0   7     5  0.728126  0.869099  6.545455
# 18     18  C1456   4.665618     1.0   7     5  0.944322  1.223176  6.545455
# 19     19  C1456   4.665618     1.0   7     5  0.944322  0.364807  6.545455
#
#     자격유형     임대보증금       임대료  도보 10분거리 내 지하철역 수(환승노선 수 반영)  \
# 0      7  0.449034  0.195940                           0.0
# 1      0  0.731320  0.263924                           0.0
# 2      7  0.731320  0.263924                           0.0
# 3      7  0.731320  0.263924                           0.0
# 4      7  0.890402  0.316928                           0.0
# 5      7  0.890402  0.316928                           0.0
# 6      7  0.890402  0.316928                           0.0
# 7      7  0.890402  0.316928                           0.0
# 8      7  0.449034  0.195940                           0.0
# 9      7  0.449034  0.195940                           0.0
# 10     0  0.449034  0.195940                           0.0
# 11     0  0.731320  0.263924                           0.0
# 12     0  0.731320  0.263924                           0.0
# 13     7  0.731320  0.263924                           0.0
# 14     0  0.890402  0.316928                           0.0
# 15     7  0.890402  0.316928                           0.0
# 16     7  0.890402  0.316928                           0.0
# 17     0  0.382317  0.157881                           0.0
# 18     0  0.526023  0.198667                           0.0
# 19     0  0.526023  0.198667                           0.0
#
#     도보 10분거리 내 버스정류장 수    단지내주차면수        등록차량수     코드별차량수평균
# 0                  2.0   7.507003   615.725605   672.363691
# 1                  2.0   7.507003   657.631795   672.363691
# 2                  2.0   7.507003   661.864672   672.363691
# 3                  2.0   7.507003   662.583478   672.363691
# 4                  2.0   7.507003   690.998340   672.363691
# 5                  2.0   7.507003   691.036220   672.363691
# 6                  2.0   7.507003   703.750983   672.363691
# 7                  2.0   7.507003   695.318438   672.363691
# 8                  3.0  13.478992   900.243233  1044.104773
# 9                  3.0  13.478992   897.399856  1044.104773
# 10                 3.0  13.478992  1009.863129  1044.104773
# 11                 3.0  13.478992  1138.248309  1044.104773
# 12                 3.0  13.478992  1184.808247  1044.104773
# 13                 3.0  13.478992  1009.621198  1044.104773
# 14                 3.0  13.478992  1166.471683  1044.104773
# 15                 3.0  13.478992  1017.436805  1044.104773
# 16                 3.0  13.478992  1072.850496  1044.104773
# 17                16.0   5.983193   498.991089   559.325556
# 18                16.0   5.983193   527.431013   559.325556
# 19                16.0   5.983193   535.997335   559.325556

# %%
test_new = test.drop_duplicates(['단지코드'], keep='first').reset_index()

sub_df = test_new[['단지코드', '코드별차량수평균']]
sub_df.columns = ['code', 'num']

sub_df
# Out:
#       code          num
# 0    C1072   672.363691
# 1    C1128  1044.104773
# 2    C1456   559.325556
# 3    C1840   501.633572
# 4    C1332   943.433962
# ..     ...          ...
# 142  C2456   282.606376
# 143  C1266   446.970202
# 144  C2152    19.773334
# 145  C1267   369.194638
# 146  C2189   320.990891
#
# [147 rows x 2 columns]

# %%
sub_df.to_csv('07_17_third_submit.csv', index=False)

import os

os.listdir(os.getcwd())
# Out:
# ['.ipynb_checkpoints',
#  '07_17_second_submit.csv',
#  '07_17_submit.csv',
#  '07_17_third_submit.csv',
#  'parking_data_preprocessing_test.csv',
#  'parking_data_preprocessing_train.csv',
#  'Parking_demand_07_12(1).ipynb',
#  'Parking_demand_07_12(2).ipynb',
#  'Parking_demand_07_14.ipynb',
#  'Parking_demand_07_16.ipynb',
#  'Parking_demand_07_17.ipynb',
#  'Parking_demand_data_error.ipynb',
#  'second_rf_0712.csv']

# %% [markdown]
# ### 118.43755점 / (259위 / 425위)
#
# 1 % : 90.66564
#
# 4 % : 94.74703
#
# 10 % : 98.53061
#
# 100위 : 105.59628

# %% [markdown]
# ### 다음에 시도할 내용
# - KNN으로 도전
#
# - train dataset으로 어떤 feature 조합이 제일 정확도가 높은지 알아보기
#
# - RandomForestRegression으로 도전
